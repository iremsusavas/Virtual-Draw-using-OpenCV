# %%
import cv2
import numpy as np

# %%
def center_handler(x,y,w,h):
    x1 = int(w/2)
    y1 = int(h/2)
    cx = x+x1
    cy = y+y1
    return cx,cy

detect= []
offset = 6 #allowable error
counter = 0
#web camera
capture = cv2.VideoCapture('video.mp4')
count_line_position = 550

#Gaussian Mixture-based Background/Foreground Segmentation Algorithm:
segmentation = cv2.createBackgroundSubtractorMOG2()
while True:
    success ,img1 = capture.read()
    
    gray = cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray,(3,3),5)
    img_subtracted_background = segmentation.apply(blur)
    dilation = cv2.dilate(img_subtracted_background,np.ones(5))
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(5,5))
    dil = cv2.morphologyEx(dilation,cv2.MORPH_CLOSE,kernel)
    dil2 = cv2.morphologyEx(dil,cv2.MORPH_CLOSE,kernel)
    countershape,h = cv2.findContours(dil2,cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    cv2.line(img1,(25,count_line_position),(1200,count_line_position),(255,127,0),3)
    for (i,c) in enumerate(countershape):
        (x,y,w,h) = cv2.boundingRect(c)
        validate_counter = (w>=80) and (h>=80)
        if not validate_counter:
            continue
        cv2.rectangle(img1,(x,y),(x+w,y+h),(0,0,255),2)
        center = center_handler(x,y,w,h)
        detect.append(center)
        cv2.circle(img1,center,4,(0,0,255),-1)
        for (x,y) in detect:
            if x<(count_line_position+offset) and y<(count_line_position+offset) :
                counter=counter+1
            cv2.line(img1,(25,count_line_position),(1200,count_line_position),(0,127,255),3)
            detect.remove((x,y))
        print("Vehicle Counter"+str(counter))
        #cv2.putText(img1,str(counter),(450,70),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255))
    
    
    
    cv2.imshow('Video',img1)
    if cv2.waitKey(1) == 13:
        break
        
cv2.destroyAllWindows()
capture.release()
# Out:
# Vehicle Counter0
# Vehicle Counter1
# Vehicle Counter2
# Vehicle Counter3
# Vehicle Counter4
# Vehicle Counter5
# Vehicle Counter6
# Vehicle Counter7
# Vehicle Counter8
# Vehicle Counter9
# Vehicle Counter10
# Vehicle Counter11
# Vehicle Counter12
# Vehicle Counter13
# Vehicle Counter14
# Vehicle Counter15
# Vehicle Counter16
# Vehicle Counter17
# Vehicle Counter17
# Vehicle Counter18
# Vehicle Counter18
# Vehicle Counter19
# Vehicle Counter19
# Vehicle Counter20
# Vehicle Counter20
# Vehicle Counter21
# Vehicle Counter21
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter22
# Vehicle Counter23
# Vehicle Counter23
# Vehicle Counter23
# Vehicle Counter23
# Vehicle Counter24
# Vehicle Counter25
# Vehicle Counter26
# Vehicle Counter27
# Vehicle Counter28
# Vehicle Counter29
# Vehicle Counter30
# Vehicle Counter31
# Vehicle Counter32
# Vehicle Counter33
# Vehicle Counter34
# Vehicle Counter35
# Vehicle Counter36
# Vehicle Counter37
# Vehicle Counter38
# Vehicle Counter39
# Vehicle Counter40
# Vehicle Counter41
# Vehicle Counter42
# Vehicle Counter43
# Vehicle Counter44
# Vehicle Counter45
# Vehicle Counter46
# Vehicle Counter47
# Vehicle Counter48
# Vehicle Counter49
# Vehicle Counter50
# Vehicle Counter51
# Vehicle Counter52
# Vehicle Counter53
# Vehicle Counter53
# Vehicle Counter53
# Vehicle Counter53
# Vehicle Counter53
# Vehicle Counter53
# Vehicle Counter53
# Vehicle Counter53
# Vehicle Counter53
# Vehicle Counter53
# Vehicle Counter53
# Vehicle Counter53
# Vehicle Counter53
# Vehicle Counter53
# Vehicle Counter53
# Vehicle Counter53
# Vehicle Counter53
# Vehicle Counter53
# Vehicle Counter54
# Vehicle Counter54
# Vehicle Counter55
# Vehicle Counter55
# Vehicle Counter56
# Vehicle Counter56
# Vehicle Counter56
# Vehicle Counter57
# Vehicle Counter57
# Vehicle Counter57
# Vehicle Counter58
# Vehicle Counter58
# Vehicle Counter58
# Vehicle Counter59
# Vehicle Counter59
# Vehicle Counter59
# Vehicle Counter59
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter60
# Vehicle Counter61
# Vehicle Counter62
# Vehicle Counter63
# Vehicle Counter63
# Vehicle Counter64
# Vehicle Counter64
# Vehicle Counter65
# Vehicle Counter66
# Vehicle Counter66
# Vehicle Counter67
# Vehicle Counter67
# Vehicle Counter68
# Vehicle Counter68
# Vehicle Counter69
# Vehicle Counter69
# Vehicle Counter70
# Vehicle Counter71
# Vehicle Counter72
# Vehicle Counter73
# Vehicle Counter74
# Vehicle Counter75
# Vehicle Counter76
# Vehicle Counter77
# Vehicle Counter78
# Vehicle Counter79
# Vehicle Counter80
# Vehicle Counter81
# Vehicle Counter82
# Vehicle Counter83
# Vehicle Counter84
# Vehicle Counter85
# Vehicle Counter85
# Vehicle Counter85
# Vehicle Counter85
# Vehicle Counter85
# Vehicle Counter85
# Vehicle Counter85
# Vehicle Counter85
# Vehicle Counter85
# Vehicle Counter85
# Vehicle Counter85
# Vehicle Counter85
# Vehicle Counter86
# Vehicle Counter87
# Vehicle Counter88
# Vehicle Counter89
# Vehicle Counter90
# Vehicle Counter91
# Vehicle Counter92
# Vehicle Counter93
# Vehicle Counter94
# Vehicle Counter95
# Vehicle Counter96
# Vehicle Counter96
# Vehicle Counter96
# Vehicle Counter96
# Vehicle Counter96
# Vehicle Counter96
# Vehicle Counter96
# Vehicle Counter96
# Vehicle Counter96
# Vehicle Counter96
# Vehicle Counter96
# Vehicle Counter96
# Vehicle Counter96
# Vehicle Counter96
# Vehicle Counter96
# Vehicle Counter96
# Vehicle Counter97
# Vehicle Counter97
# Vehicle Counter97
# Vehicle Counter97
# Vehicle Counter98
# Vehicle Counter99
# Vehicle Counter99
# Vehicle Counter100
# Vehicle Counter100
# Vehicle Counter100
# Vehicle Counter100
# Vehicle Counter101
# Vehicle Counter102
# Vehicle Counter102
# Vehicle Counter102
# Vehicle Counter102
# Vehicle Counter102
# Vehicle Counter103
# Vehicle Counter104
# Vehicle Counter104
# Vehicle Counter104
# Vehicle Counter105
# Vehicle Counter106
# Vehicle Counter106
# Vehicle Counter106
# Vehicle Counter107
# Vehicle Counter107
# Vehicle Counter108
# Vehicle Counter108
# Vehicle Counter108
# Vehicle Counter109
# Vehicle Counter110
# Vehicle Counter110
# Vehicle Counter110
# Vehicle Counter110
# Vehicle Counter110
# Vehicle Counter110
# Vehicle Counter110
# Vehicle Counter110
# Vehicle Counter110
# Vehicle Counter111
# Vehicle Counter111
# Vehicle Counter112
# Vehicle Counter112
# Vehicle Counter113
# Vehicle Counter113
# Vehicle Counter114
# Vehicle Counter114
# Vehicle Counter115
# Vehicle Counter115
# Vehicle Counter115
# Vehicle Counter116
# Vehicle Counter116
# Vehicle Counter117
# Vehicle Counter117
# Vehicle Counter117
# Vehicle Counter118
# Vehicle Counter119
# Vehicle Counter119
# Vehicle Counter120
# Vehicle Counter120
# Vehicle Counter120
# Vehicle Counter120
# Vehicle Counter121
# Vehicle Counter122
# Vehicle Counter123
# Vehicle Counter123
# Vehicle Counter123
# Vehicle Counter123
# Vehicle Counter123
# Vehicle Counter123
# Vehicle Counter124
# Vehicle Counter125
# Vehicle Counter126
# Vehicle Counter126
# Vehicle Counter126
# Vehicle Counter126
# Vehicle Counter126
# Vehicle Counter126
# Vehicle Counter126
# Vehicle Counter127
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter128
# Vehicle Counter129
# Vehicle Counter129
# Vehicle Counter129
# Vehicle Counter129
# Vehicle Counter129
# Vehicle Counter129
# Vehicle Counter129
# Vehicle Counter129
# Vehicle Counter129
# Vehicle Counter130
# Vehicle Counter130
# Vehicle Counter130
# Vehicle Counter130
# Vehicle Counter130
# Vehicle Counter131
# Vehicle Counter131
# Vehicle Counter131
# Vehicle Counter131
# Vehicle Counter131
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter132
# Vehicle Counter133
# Vehicle Counter133
# Vehicle Counter134
# Vehicle Counter134
# Vehicle Counter135
# Vehicle Counter135
# Vehicle Counter136
# Vehicle Counter137
# Vehicle Counter138
# Vehicle Counter139
# Vehicle Counter140
# Vehicle Counter141
# Vehicle Counter142
# Vehicle Counter143
# Vehicle Counter144
# Vehicle Counter145
# Vehicle Counter146
# Vehicle Counter147
# Vehicle Counter148
# Vehicle Counter149
# Vehicle Counter150
# Vehicle Counter151
# Vehicle Counter152
# Vehicle Counter153
# Vehicle Counter154
# Vehicle Counter154
# Vehicle Counter155
# Vehicle Counter155
# Vehicle Counter156
# Vehicle Counter156
# Vehicle Counter157
# Vehicle Counter157
# Vehicle Counter158
# Vehicle Counter158
# Vehicle Counter159
# Vehicle Counter159
# Vehicle Counter160
# Vehicle Counter160
# Vehicle Counter161
# Vehicle Counter161
# Vehicle Counter162
# Vehicle Counter162
# Vehicle Counter163
# Vehicle Counter163
# Vehicle Counter164
# Vehicle Counter164
# Vehicle Counter165
# Vehicle Counter165
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter166
# Vehicle Counter167
# Vehicle Counter168
# Vehicle Counter169
# Vehicle Counter170
# Vehicle Counter171
# Vehicle Counter172
# Vehicle Counter173
# Vehicle Counter173
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter174
# Vehicle Counter175
# Vehicle Counter176
# Vehicle Counter177
# Vehicle Counter178
# Vehicle Counter179
# Vehicle Counter180
# Vehicle Counter181
# Vehicle Counter182
# Vehicle Counter183
# Vehicle Counter184
# Vehicle Counter184
# Vehicle Counter184
# Vehicle Counter184
# Vehicle Counter184
# Vehicle Counter184
# Vehicle Counter184
# Vehicle Counter184
# Vehicle Counter184
# Vehicle Counter184
# Vehicle Counter184
# Vehicle Counter184
# Vehicle Counter185
# Vehicle Counter186
# Vehicle Counter187
# Vehicle Counter188
# Vehicle Counter189
# Vehicle Counter190
# Vehicle Counter191
# Vehicle Counter192
# Vehicle Counter193
# Vehicle Counter194
# Vehicle Counter195
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter196
# Vehicle Counter197
# Vehicle Counter198
# Vehicle Counter199
# Vehicle Counter200
# Vehicle Counter201
# Vehicle Counter202
# Vehicle Counter203
# Vehicle Counter204
# Vehicle Counter205
# Vehicle Counter206
# Vehicle Counter207
# Vehicle Counter208
# Vehicle Counter208
# Vehicle Counter208
# Vehicle Counter208
# Vehicle Counter208
# Vehicle Counter208
# Vehicle Counter208
# Vehicle Counter209
# Vehicle Counter209
# Vehicle Counter209
# Vehicle Counter209
# Vehicle Counter209
# Vehicle Counter210
# Vehicle Counter211
# Vehicle Counter212
# Vehicle Counter213
# Vehicle Counter214
# Vehicle Counter215
# Vehicle Counter216
# Vehicle Counter217
# Vehicle Counter218
# Vehicle Counter219
# Vehicle Counter220
# Vehicle Counter221
# Vehicle Counter222
# Vehicle Counter222
# Vehicle Counter222
# Vehicle Counter222
# Vehicle Counter222
# Vehicle Counter222
# Vehicle Counter222
# Vehicle Counter222
# Vehicle Counter222
# Vehicle Counter222
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3234/1183696603.py in <module>
#      25     dil = cv2.morphologyEx(dilation,cv2.MORPH_CLOSE,kernel)
#      26     dil2 = cv2.morphologyEx(dil,cv2.MORPH_CLOSE,kernel)
# ---> 27     countershape,h = cv2.findContours(dil2,cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
#      28     cv2.line(img1,(25,count_line_position),(1200,count_line_position),(255,127,0),3)
#      29     for (i,c) in enumerate(countershape):
#
# KeyboardInterrupt:
